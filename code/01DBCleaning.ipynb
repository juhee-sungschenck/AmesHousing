# %%
# import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn import metrics

# %%
# read in the data

house = pd.read_csv('../datasets/train.csv')
print(house.shape)
house.head()
# Out:
# (2051, 81)
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour  ... Screen Porch Pool Area Pool QC Fence  \
# 0       IR1          Lvl  ...            0         0     NaN   NaN
# 1       IR1          Lvl  ...            0         0     NaN   NaN
# 2       Reg          Lvl  ...            0         0     NaN   NaN
# 3       Reg          Lvl  ...            0         0     NaN   NaN
# 4       IR1          Lvl  ...            0         0     NaN   NaN
#
#   Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  SalePrice
# 0          NaN        0       3    2010        WD      130500
# 1          NaN        0       4    2009        WD      220000
# 2          NaN        0       1    2010        WD      109000
# 3          NaN        0       4    2010        WD      174000
# 4          NaN        0       3    2010        WD      138500
#
# [5 rows x 81 columns]

# %%
# check for missing values

house.isnull().sum().sort_values(ascending = False)
# Out:
# Pool QC         2042
# Misc Feature    1986
# Alley           1911
# Fence           1651
# Fireplace Qu    1000
#                 ...
# Electrical         0
# Central Air        0
# Heating QC         0
# Sale Type          0
# Id                 0
# Length: 81, dtype: int64

# %%
# check the pct of missingness - prep for dropping values

missing = pd.DataFrame({
                        'total': house.isnull().sum(),
                        'pct': house.isnull().sum()/2051
})

# %%
# save the missingness dataset to csv file

missing.sort_values(by = 'total', ascending = False)
missing.to_csv('../datasets/missing.csv', index = False)

# pool qc. misc feature, alley, and fence have mostly missing (over 80%). will drop these columns.

# need to fill 0, none, or median, depending on the variables.

# columns are - 

# lot frontage --> median
# bsmt full/half bath, garage cars/area, bsmt fin sf 1/fin sf 2/unf sf, mas vnr area --> 0
# fire place qu, garage type/finish/qual/cond, bsmt qual/cond/exposure/fin type1/fin type 2, mas vnr type --> none

# %%
# check for missing values that are related to garage

house.loc[(house['Garage Type'].isnull() == True) | (house['Garage Yr Blt'].isnull() == True) | (house['Garage Finish'].isnull() == True) | (house['Garage Cars'].isnull() == True) | 
          (house['Garage Area'].isnull() == True) | (house['Garage Qual'].isnull() == True) | (house['Garage Cond'].isnull() == True)][['Garage Type', 'Garage Yr Blt', 'Garage Finish', 'Garage Cars', 'Garage Area', 'Garage Qual', 'Garage Cond']]
# Out:
#      Garage Type  Garage Yr Blt Garage Finish  Garage Cars  Garage Area  \
# 28           NaN            NaN           NaN          0.0          0.0
# 53           NaN            NaN           NaN          0.0          0.0
# 65           NaN            NaN           NaN          0.0          0.0
# 79           NaN            NaN           NaN          0.0          0.0
# 101          NaN            NaN           NaN          0.0          0.0
# ...          ...            ...           ...          ...          ...
# 1991         NaN            NaN           NaN          0.0          0.0
# 2010         NaN            NaN           NaN          0.0          0.0
# 2027         NaN            NaN           NaN          0.0          0.0
# 2039         NaN            NaN           NaN          0.0          0.0
# 2042         NaN            NaN           NaN          0.0          0.0
#
#      Garage Qual Garage Cond
# 28           NaN         NaN
# 53           NaN         NaN
# 65           NaN         NaN
# 79           NaN         NaN
# 101          NaN         NaN
# ...          ...         ...
# 1991         NaN         NaN
# 2010         NaN         NaN
# 2027         NaN         NaN
# 2039         NaN         NaN
# 2042         NaN         NaN
#
# [114 rows x 7 columns]

# %%
# drop columns that contain over 80% values

house.drop(columns = ['Pool QC', 'Misc Feature', 'Alley', 'Fence'], axis = 1, inplace = True)

# %%
# fill missing values with 0, NA, or None

for col in house.columns:
    if col in ['Bsmt Full Bath', 'Bsmt Half Bath', 'Garage Cars', 'Garage Area', 'BsmtFin SF 1', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Mas Vnr Area', 'Garage Yr Blt', 'Total Bsmt SF']:
        house[col].fillna(0, inplace = True)
    elif col in ['Fireplace Qu', 'Garage Type', 'Garage Finish', 'Garage Qual', 'Garage Cond', 'Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin Type 2']:
        house[col].fillna('NA', inplace = True)
    elif col in ['Mas Vnr Type']:
        house[col].fillna('None', inplace = True)
    else:
        pass

# %%
# check for missing values again

house.isnull().sum().sort_values(ascending = False)
# Out:
# Lot Frontage     330
# SalePrice          0
# Exter Cond         0
# Roof Style         0
# Roof Matl          0
#                 ...
# Bedroom AbvGr      0
# Kitchen AbvGr      0
# Kitchen Qual       0
# TotRms AbvGrd      0
# Id                 0
# Length: 77, dtype: int64

# %%
# filling with median

house['Lot Frontage'] = house.groupby('Neighborhood')['Lot Frontage'].apply(lambda x: x.fillna(x.median())) 
# --> still 3 nan values, will fill it with median lot size for the ground living area

house['Lot Frontage'] = house.groupby('Gr Liv Area')['Lot Frontage'].apply(lambda x: x.fillna(x.median())) 
# --> still 1 nan value, will fill it with median for ground living area between 1290 and 1300

house.loc[(house['Gr Liv Area'] < 1300) & (house['Gr Liv Area'] > 1290)][['Lot Frontage', 'Neighborhood', 'Gr Liv Area']].sort_values(by = 'Lot Frontage') 
# --> replace NaN with 67.0

house['Lot Frontage'].fillna(67.0, inplace = True)

# %%
# only keep residential tags

house['MS Zoning'].value_counts()

house = house[house['MS Zoning'].isin(['RH', 'RL', 'RP', 'RM'])].reset_index(drop = True)

house.shape
# Out:
# (1928, 77)

# %%
# check the sq ft information

house[['1st Flr SF', '2nd Flr SF', 'Gr Liv Area', 'BsmtFin SF 1', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF']]
# Out:
#       1st Flr SF  2nd Flr SF  Gr Liv Area  BsmtFin SF 1  BsmtFin SF 2  \
# 0            725         754         1479         533.0           0.0
# 1            913        1209         2122         637.0           0.0
# 2           1057           0         1057         731.0           0.0
# 3            744         700         1444           0.0           0.0
# 4            831         614         1445           0.0           0.0
# ...          ...         ...          ...           ...           ...
# 1923        1728           0         1728        1011.0           0.0
# 1924         861           0          861         262.0           0.0
# 1925        1172         741         1913           0.0           0.0
# 1926        1200           0         1200         155.0         750.0
# 1927        1028         776         1804           0.0           0.0
#
#       Bsmt Unf SF  Total Bsmt SF
# 0           192.0          725.0
# 1           276.0          913.0
# 2           326.0         1057.0
# 3           384.0          384.0
# 4           676.0          676.0
# ...           ...            ...
# 1923        873.0         1884.0
# 1924        599.0          861.0
# 1925        896.0          896.0
# 1926        295.0         1200.0
# 1927        994.0          994.0
#
# [1928 rows x 7 columns]

# %%
# change the column names for me to type better

house.columns = house.columns.str.replace(' ', '_')
house.columns = house.columns.str.lower()

# %%
# make sure if the null values are all filled

house['total_bsmt_sf'] = house['total_bsmt_sf'].fillna(0)
house['total_sf'] = house['gr_liv_area'] + house['total_bsmt_sf']
house.loc[house['total_sf'].isnull() == True][['gr_liv_area', 'total_bsmt_sf', 'total_sf']]
# Out:
# Empty DataFrame
# Columns: [gr_liv_area, total_bsmt_sf, total_sf]
# Index: []

# %%
# check columns if everything looks good

house.columns
# Out:
# Index(['id', 'pid', 'ms_subclass', 'ms_zoning', 'lot_frontage', 'lot_area',
#        'street', 'lot_shape', 'land_contour', 'utilities', 'lot_config',
#        'land_slope', 'neighborhood', 'condition_1', 'condition_2', 'bldg_type',
#        'house_style', 'overall_qual', 'overall_cond', 'year_built',
#        'year_remod/add', 'roof_style', 'roof_matl', 'exterior_1st',
#        'exterior_2nd', 'mas_vnr_type', 'mas_vnr_area', 'exter_qual',
#        'exter_cond', 'foundation', 'bsmt_qual', 'bsmt_cond', 'bsmt_exposure',
#        'bsmtfin_type_1', 'bsmtfin_sf_1', 'bsmtfin_type_2', 'bsmtfin_sf_2',
#        'bsmt_unf_sf', 'total_bsmt_sf', 'heating', 'heating_qc', 'central_air',
#        'electrical', '1st_flr_sf', '2nd_flr_sf', 'low_qual_fin_sf',
#        'gr_liv_area', 'bsmt_full_bath', 'bsmt_half_bath', 'full_bath',
#        'half_bath', 'bedroom_abvgr', 'kitchen_abvgr', 'kitchen_qual',
#        'totrms_abvgrd', 'functional', 'fireplaces', 'fireplace_qu',
#        'garage_type', 'garage_yr_blt', 'garage_finish', 'garage_cars',
#        'garage_area', 'garage_qual', 'garage_cond', 'paved_drive',
#        'wood_deck_sf', 'open_porch_sf', 'enclosed_porch', '3ssn_porch',
#        'screen_porch', 'pool_area', 'misc_val', 'mo_sold', 'yr_sold',
#        'sale_type', 'saleprice', 'total_sf'],
#       dtype='object')

# %%
# check the data

house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1928 entries, 0 to 1927
# Data columns (total 78 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1928 non-null   int64
#  1   pid              1928 non-null   int64
#  2   ms_subclass      1928 non-null   int64
#  3   ms_zoning        1928 non-null   object
#  4   lot_frontage     1928 non-null   float64
#  5   lot_area         1928 non-null   int64
#  6   street           1928 non-null   object
#  7   lot_shape        1928 non-null   object
#  8   land_contour     1928 non-null   object
#  9   utilities        1928 non-null   object
#  10  lot_config       1928 non-null   object
#  11  land_slope       1928 non-null   object
#  12  neighborhood     1928 non-null   object
#  13  condition_1      1928 non-null   object
#  14  condition_2      1928 non-null   object
#  15  bldg_type        1928 non-null   object
#  16  house_style      1928 non-null   object
#  17  overall_qual     1928 non-null   int64
#  18  overall_cond     1928 non-null   int64
#  19  year_built       1928 non-null   int64
#  20  year_remod/add   1928 non-null   int64
#  21  roof_style       1928 non-null   object
#  22  roof_matl        1928 non-null   object
#  23  exterior_1st     1928 non-null   object
#  24  exterior_2nd     1928 non-null   object
#  25  mas_vnr_type     1928 non-null   object
#  26  mas_vnr_area     1928 non-null   float64
#  27  exter_qual       1928 non-null   object
#  28  exter_cond       1928 non-null   object
#  29  foundation       1928 non-null   object
#  30  bsmt_qual        1928 non-null   object
#  31  bsmt_cond        1928 non-null   object
#  32  bsmt_exposure    1928 non-null   object
#  33  bsmtfin_type_1   1928 non-null   object
#  34  bsmtfin_sf_1     1928 non-null   float64
#  35  bsmtfin_type_2   1928 non-null   object
#  36  bsmtfin_sf_2     1928 non-null   float64
#  37  bsmt_unf_sf      1928 non-null   float64
#  38  total_bsmt_sf    1928 non-null   float64
#  39  heating          1928 non-null   object
#  40  heating_qc       1928 non-null   object
#  41  central_air      1928 non-null   object
#  42  electrical       1928 non-null   object
#  43  1st_flr_sf       1928 non-null   int64
#  44  2nd_flr_sf       1928 non-null   int64
#  45  low_qual_fin_sf  1928 non-null   int64
#  46  gr_liv_area      1928 non-null   int64
#  47  bsmt_full_bath   1928 non-null   float64
#  48  bsmt_half_bath   1928 non-null   float64
#  49  full_bath        1928 non-null   int64
#  50  half_bath        1928 non-null   int64
#  51  bedroom_abvgr    1928 non-null   int64
#  52  kitchen_abvgr    1928 non-null   int64
#  53  kitchen_qual     1928 non-null   object
#  54  totrms_abvgrd    1928 non-null   int64
#  55  functional       1928 non-null   object
#  56  fireplaces       1928 non-null   int64
#  57  fireplace_qu     1928 non-null   object
#  58  garage_type      1928 non-null   object
#  59  garage_yr_blt    1928 non-null   float64
#  60  garage_finish    1928 non-null   object
#  61  garage_cars      1928 non-null   float64
#  62  garage_area      1928 non-null   float64
#  63  garage_qual      1928 non-null   object
#  64  garage_cond      1928 non-null   object
#  65  paved_drive      1928 non-null   object
#  66  wood_deck_sf     1928 non-null   int64
#  67  open_porch_sf    1928 non-null   int64
#  68  enclosed_porch   1928 non-null   int64
#  69  3ssn_porch       1928 non-null   int64
#  70  screen_porch     1928 non-null   int64
#  71  pool_area        1928 non-null   int64
#  72  misc_val         1928 non-null   int64
#  73  mo_sold          1928 non-null   int64
#  74  yr_sold          1928 non-null   int64
#  75  sale_type        1928 non-null   object
#  76  saleprice        1928 non-null   int64
#  77  total_sf         1928 non-null   float64
# dtypes: float64(12), int64(28), object(38)
# memory usage: 1.1+ MB

# %%
# follow above steps for the test dataset as well
# read in test data

test = pd.read_csv('../datasets/test.csv')

# %%
print(test.shape)
test.isnull().sum().sort_values(ascending = False)
# Out:
# (878, 80)
# Pool QC         874
# Misc Feature    837
# Alley           820
# Fence           706
# Fireplace Qu    422
#                ...
# Heating QC        0
# Heating           0
# Yr Sold           0
# Bsmt Unf SF       0
# Id                0
# Length: 80, dtype: int64

# %%
# drop columns

test.drop(columns = ['Pool QC', 'Misc Feature', 'Fence', 'Alley'], axis = 1, inplace = True)

# %%
test.shape
# Out:
# (878, 76)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 878 entries, 0 to 877
# Data columns (total 76 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Id               878 non-null    int64
#  1   PID              878 non-null    int64
#  2   MS SubClass      878 non-null    int64
#  3   MS Zoning        878 non-null    object
#  4   Lot Frontage     718 non-null    float64
#  5   Lot Area         878 non-null    int64
#  6   Street           878 non-null    object
#  7   Lot Shape        878 non-null    object
#  8   Land Contour     878 non-null    object
#  9   Utilities        878 non-null    object
#  10  Lot Config       878 non-null    object
#  11  Land Slope       878 non-null    object
#  12  Neighborhood     878 non-null    object
#  13  Condition 1      878 non-null    object
#  14  Condition 2      878 non-null    object
#  15  Bldg Type        878 non-null    object
#  16  House Style      878 non-null    object
#  17  Overall Qual     878 non-null    int64
#  18  Overall Cond     878 non-null    int64
#  19  Year Built       878 non-null    int64
#  20  Year Remod/Add   878 non-null    int64
#  21  Roof Style       878 non-null    object
#  22  Roof Matl        878 non-null    object
#  23  Exterior 1st     878 non-null    object
#  24  Exterior 2nd     878 non-null    object
#  25  Mas Vnr Type     877 non-null    object
#  26  Mas Vnr Area     877 non-null    float64
#  27  Exter Qual       878 non-null    object
#  28  Exter Cond       878 non-null    object
#  29  Foundation       878 non-null    object
#  30  Bsmt Qual        853 non-null    object
#  31  Bsmt Cond        853 non-null    object
#  32  Bsmt Exposure    853 non-null    object
#  33  BsmtFin Type 1   853 non-null    object
#  34  BsmtFin SF 1     878 non-null    int64
#  35  BsmtFin Type 2   853 non-null    object
#  36  BsmtFin SF 2     878 non-null    int64
#  37  Bsmt Unf SF      878 non-null    int64
#  38  Total Bsmt SF    878 non-null    int64
#  39  Heating          878 non-null    object
#  40  Heating QC       878 non-null    object
#  41  Central Air      878 non-null    object
#  42  Electrical       877 non-null    object
#  43  1st Flr SF       878 non-null    int64
#  44  2nd Flr SF       878 non-null    int64
#  45  Low Qual Fin SF  878 non-null    int64
#  46  Gr Liv Area      878 non-null    int64
#  47  Bsmt Full Bath   878 non-null    int64
#  48  Bsmt Half Bath   878 non-null    int64
#  49  Full Bath        878 non-null    int64
#  50  Half Bath        878 non-null    int64
#  51  Bedroom AbvGr    878 non-null    int64
#  52  Kitchen AbvGr    878 non-null    int64
#  53  Kitchen Qual     878 non-null    object
#  54  TotRms AbvGrd    878 non-null    int64
#  55  Functional       878 non-null    object
#  56  Fireplaces       878 non-null    int64
#  57  Fireplace Qu     456 non-null    object
#  58  Garage Type      834 non-null    object
#  59  Garage Yr Blt    833 non-null    float64
#  60  Garage Finish    833 non-null    object
#  61  Garage Cars      878 non-null    int64
#  62  Garage Area      878 non-null    int64
#  63  Garage Qual      833 non-null    object
#  64  Garage Cond      833 non-null    object
#  65  Paved Drive      878 non-null    object
#  66  Wood Deck SF     878 non-null    int64
#  67  Open Porch SF    878 non-null    int64
#  68  Enclosed Porch   878 non-null    int64
#  69  3Ssn Porch       878 non-null    int64
#  70  Screen Porch     878 non-null    int64
#  71  Pool Area        878 non-null    int64
#  72  Misc Val         878 non-null    int64
#  73  Mo Sold          878 non-null    int64
#  74  Yr Sold          878 non-null    int64
#  75  Sale Type        878 non-null    object
# dtypes: float64(3), int64(35), object(38)
# memory usage: 521.4+ KB

# %%
# fill with 0, NA, or None

for col in test.columns:
    if col in ['Bsmt Full Bath', 'Bsmt Half Bath', 'Garage Cars', 'Garage Area', 'BsmtFin SF 1', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Mas Vnr Area', 'Garage Yr Blt', 'Total Bsmt SF']:
        test[col].fillna(0, inplace = True)
    elif col in ['Fireplace Qu', 'Garage Type', 'Garage Finish', 'Garage Qual', 'Garage Cond', 'Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin Type 2']:
        test[col].fillna('NA', inplace = True)
    elif col in ['Mas Vnr Type']:
        test[col].fillna('None', inplace = True)
    else:
        pass

# %%
test.isnull().sum().sort_values(ascending = False)
# Out:
# Lot Frontage     160
# Electrical         1
# Sale Type          0
# Exter Qual         0
# Roof Style         0
#                 ...
# Bedroom AbvGr      0
# Kitchen AbvGr      0
# Kitchen Qual       0
# TotRms AbvGrd      0
# Id                 0
# Length: 76, dtype: int64

# %%
# fill with median

test['Lot Frontage'] = test.groupby('Neighborhood')['Lot Frontage'].apply(lambda x: x.fillna(x.median()))

# %%
test['Electrical'].mode()
# Out:
# 0    SBrkr
# dtype: object

# %%
# fill with mode

test.loc[test['Electrical'].isnull() == True][['Id', 'Electrical']]
test['Electrical'].replace(to_replace = np.NaN, value = 'SBrkr', inplace = True)

# %%
test.shape
# Out:
# (878, 76)

# %%
test[['1st Flr SF', '2nd Flr SF', 'Gr Liv Area', 'BsmtFin SF 1', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF']]
# Out:
#      1st Flr SF  2nd Flr SF  Gr Liv Area  BsmtFin SF 1  BsmtFin SF 2  \
# 0           908        1020         1928             0             0
# 1          1967           0         1967             0             0
# 2           664         832         1496           554             0
# 3           968           0          968             0             0
# 4          1394           0         1394           609             0
# ..          ...         ...          ...           ...           ...
# 873        1084         793         1877           931           153
# 874        1104         884         1988           575             0
# 875        1211           0         1211           250           492
# 876         864           0          864           616             0
# 877         925           0          925           793             0
#
#      Bsmt Unf SF  Total Bsmt SF
# 0           1020           1020
# 1           1967           1967
# 2            100            654
# 3            968            968
# 4            785           1394
# ..           ...            ...
# 873            0           1084
# 874          529           1104
# 875          210            952
# 876          248            864
# 877          130            923
#
# [878 rows x 7 columns]

# %%
# change the column names - no uppercase, no space

test.columns = test.columns.str.replace(' ', '_')
test.columns = test.columns.str.lower()

# %%
# take care of the null values

test['total_bsmt_sf'] = test['total_bsmt_sf'].fillna(0)
test['total_sf'] = test['gr_liv_area'] + test['total_bsmt_sf']
test.loc[test['total_sf'].isnull() == True][['gr_liv_area', 'total_bsmt_sf', 'total_sf']]
# Out:
# Empty DataFrame
# Columns: [gr_liv_area, total_bsmt_sf, total_sf]
# Index: []

# %%
test.head()
# Out:
#      id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 0  2658  902301120          190        RM          69.0      9142   Pave
# 1  2718  905108090           90        RL          75.0      9662   Pave
# 2  2414  528218130           60        RL          58.0     17104   Pave
# 3  1989  902207150           30        RM          60.0      8520   Pave
# 4   625  535105100           20        RL          74.5      9500   Pave
#
#   lot_shape land_contour utilities  ... open_porch_sf enclosed_porch  \
# 0       Reg          Lvl    AllPub  ...            60            112
# 1       IR1          Lvl    AllPub  ...             0              0
# 2       IR1          Lvl    AllPub  ...            24              0
# 3       Reg          Lvl    AllPub  ...             0            184
# 4       IR1          Lvl    AllPub  ...            76              0
#
#   3ssn_porch screen_porch pool_area misc_val mo_sold  yr_sold  sale_type  \
# 0          0            0         0        0       4     2006        WD
# 1          0            0         0        0       8     2006        WD
# 2          0            0         0        0       9     2006        New
# 3          0            0         0        0       7     2007        WD
# 4          0          185         0        0       7     2009        WD
#
#    total_sf
# 0      2948
# 1      3934
# 2      2150
# 3      1936
# 4      2788
#
# [5 rows x 77 columns]

# %%
# use id column as index

house.set_index('id', inplace = True)
test.set_index('id', inplace = True)

# %%
house.head(2)
# Out:
#            pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# id
# 109  533352170           60        RL          70.0     13517   Pave
# 544  531379050           60        RL          43.0     11492   Pave
#
#     lot_shape land_contour utilities lot_config  ... enclosed_porch  \
# id                                               ...
# 109       IR1          Lvl    AllPub    CulDSac  ...              0
# 544       IR1          Lvl    AllPub    CulDSac  ...              0
#
#     3ssn_porch screen_porch pool_area misc_val mo_sold  yr_sold  sale_type  \
# id
# 109          0            0         0        0       3     2010        WD
# 544          0            0         0        0       4     2009        WD
#
#      saleprice  total_sf
# id
# 109     130500    2204.0
# 544     220000    3035.0
#
# [2 rows x 77 columns]

# %%
test.head(2)
# Out:
#             pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# id
# 2658  902301120          190        RM          69.0      9142   Pave
# 2718  905108090           90        RL          75.0      9662   Pave
#
#      lot_shape land_contour utilities lot_config  ... open_porch_sf  \
# id                                                ...
# 2658       Reg          Lvl    AllPub     Inside  ...            60
# 2718       IR1          Lvl    AllPub     Inside  ...             0
#
#      enclosed_porch 3ssn_porch screen_porch pool_area misc_val  mo_sold  \
# id
# 2658            112          0            0         0        0        4
# 2718              0          0            0         0        0        8
#
#       yr_sold  sale_type  total_sf
# id
# 2658     2006        WD       2948
# 2718     2006        WD       3934
#
# [2 rows x 76 columns]

# %%
# store datasets as csv

house.to_csv('../datasets/train_clean.csv')
test.to_csv('../datasets/test_clean.csv')
